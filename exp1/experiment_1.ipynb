# %%
import numpy as np
import matplotlib.pyplot as plt


t = 60
v= np.array([365,386,405,304,326,344,333,337,339,350,342,423,442,463,485,506,493])
count = np.array([4736,4951,5129,0,0,3796,0,10,1423,4319,3462,5223,5215,5248,5264,5481,5326])

plt.grid(1)
plt.scatter(v,count)


rc = 5326
rb = 4736
vc = 493
vb = 365

ps = (20000*(rc-rb)/(rc+rb))/(vc-vb)
print(ps)
plt.savefig("experiment_1_fig1.svg")
# Out:
# 9.161945935201748
